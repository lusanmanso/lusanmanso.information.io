# %% [markdown]
# # Ejercicios de BeautifulSoup
#
# 1. **Extrayendo el Título de una Página de Wikipedia**
#    - Escribe un script en Python usando BeautifulSoup para extraer e imprimir el título de la página de Wikipedia para "Python (lenguaje de programación)".
#
# 2. **Extrayendo Todos los Encabezados**
#    - Escribe un script para extraer e imprimir todos los encabezados (h1, h2, h3, etc.) de la página de Wikipedia para "Web scraping".
#
# 3. **Extrayendo el Primer Párrafo**
#    - Escribe un script para extraer e imprimir el primer párrafo de la página de Wikipedia para "Data Science".
#
# 4. **Extrayendo Todos los Enlaces**
#    - Escribe un script para extraer e imprimir todos los hipervínculos (URLs) de la página de Wikipedia para "Machine Learning".
#
# 5. **Extrayendo la Tabla de Contenidos**
#    - Escribe un script para extraer e imprimir la tabla de contenidos de la página de Wikipedia para "Artificial Intelligence".
#
# 6. **Extrayendo Datos del Infobox**
#    - Escribe un script para extraer e imprimir los datos del infobox (la caja en el lado derecho) de la página de Wikipedia para "Alan Turing".
#
# 7. **Extrayendo Referencias**
#    - Escribe un script para extraer e imprimir todas las referencias (citas) de la página de Wikipedia para "Quantum Computing".
#
# 8. **Extrayendo Todas las Imágenes**
#    - Escribe un script en Python usando BeautifulSoup para extraer e imprimir todas las URLs de imágenes de la página de Wikipedia para "Computer Science".
#
# 9. **Extrayendo Todas las Tablas**
#    - Escribe un script para extraer e imprimir todas las tablas de la página de Wikipedia para "List of programming languages".
#
# 10. **Extrayendo Todos los Enlaces Externos**
#     - Escribe un script para extraer e imprimir todos los enlaces externos (enlaces que llevan a otros sitios web) de la página de Wikipedia para "Internet".

# %%
# Ejercicio 1: Extrayendo el Título de una Página de Wikipedia

# %%
# Ejercicio 2: Extrayendo Todos los Encabezados

# %%
# Ejercicio 3: Extrayendo el Primer Párrafo

# %%
# Ejercicio 4: Extrayendo Todos los Enlaces

# %%
# Ejercicio 5: Extrayendo la Tabla de Contenidos

# %%
# Ejercicio 6: Extrayendo Datos del Infobox

# %%
# Ejercicio 7: Extrayendo Referencias

# %%
# Ejercicio 8: Extrayendo Todas las Imágenes

# %%
# Ejercicio 9: Extrayendo Todas las Tablas

# %%
# Ejercicio 10: Extrayendo Todos los Enlaces Externos
